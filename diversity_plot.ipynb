# %%
#Load libraries
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import math as math

# %%
data = np.zeros((1000, 2))

# %%
num = 1
for row in range(0,1000):
    data[row][0] = num
    num += 1

# %%
broadness = 50
exponentiality = 1
for row in range(0,1000):
    data[row][1] = math.exp(exponentiality/broadness*(data[row][0]))

# %%
print(data)
# Out:
# [[1.00000000e+00 1.02020134e+00]
#  [2.00000000e+00 1.04081077e+00]
#  [3.00000000e+00 1.06183655e+00]
#  ...
#  [9.98000000e+02 4.66141596e+08]
#  [9.99000000e+02 4.75558281e+08]
#  [1.00000000e+03 4.85165195e+08]]

# %%
plt.figure(figsize = (10, 10))
plt.scatter(data[:,0], data[:,1])
plt.show()
